# %%
import sympy as sp

# Define symbols
x, y = sp.symbols('x y')

# Define the function
f = sp.exp(x) * sp.sin(y) + y**3

# Calculate the partial derivative with respect to x
df_dx = sp.diff(f, x)
print("Partial derivative with respect to x:", df_dx)

# Calculate the partial derivative with respect to y
df_dy = sp.diff(f, y)
print("Partial derivative with respect to y:", df_dy)
# Out:
# Partial derivative with respect to x: exp(x)*sin(y)
# Partial derivative with respect to y: 3*y**2 + exp(x)*cos(y)

# %%
import sympy as sp

# Define symbols
x, y = sp.symbols('x y')

# Define the function
f = x**2 * y + x * y**2

# Calculate partial derivatives
df_dx = sp.diff(f, x)
df_dy = sp.diff(f, y)

# Calculate gradient
gradient = df_dx + df_dy

# Define point
x_val = 1
y_val = -1

# Define function to compute gradient at a point
def gradient_at_point(x, y):
    return x**2 + 2 * x * y

print("Gradient at (1, -1) is:", gradient_at_point(x_val, y_val))

# Define function to compute magnitude
def magnitude(x, y):
    return sp.sqrt((gradient_at_point(x, y))**2 + (gradient_at_point(x, y))**2)

print("Magnitude at (1, -1) is:", magnitude(x_val, y_val))
# Out:
# Gradient at (1, -1) is: -1
# Magnitude at (1, -1) is: sqrt(2)

# %%
import sympy as sp

# Define symbols
x, y = sp.symbols('x y')

# Define the function
f = sp.log(x**2 + y**2)

# Calculate second partial derivatives
second_derivative_x = sp.diff(sp.diff(f, x), x)  # Second derivative with respect to x
second_derivative_y = sp.diff(sp.diff(f, y), y)  # Second derivative with respect to y
mixed_derivative = sp.diff(sp.diff(f, x), y)     # Mixed partial derivative

# Output the results
print("Second derivative with respect to x:", second_derivative_x)
print("Second derivative with respect to y:", second_derivative_y)
print("Mixed partial derivative:", mixed_derivative)

# Comment on symmetry
print("\nAccording to Clairaut's Theorem, the mixed partial derivatives (fxy and fyx) are symmetrical.")
print("Hence, fxy(x, y) =", mixed_derivative, "and fyx(x, y) =", mixed_derivative, "will be the same.")
# Out:
# Second derivative with respect to x: -4*x**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
# Second derivative with respect to y: -4*y**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
# Mixed partial derivative: -4*x*y/(x**2 + y**2)**2
#
# According to Clairaut's Theorem, the mixed partial derivatives (fxy and fyx) are symmetrical.
# Hence, fxy(x, y) = -4*x*y/(x**2 + y**2)**2 and fyx(x, y) = -4*x*y/(x**2 + y**2)**2 will be the same.

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define symbols
x, y = sp.symbols('x y')

# Define the function
j = x**2 - 2*x*y + y**2

# Convert the function to a numpy-compatible function
j_func = sp.lambdify((x, y), j, 'numpy')

# Generate x and y values
x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)

# Create a meshgrid
X, Y = np.meshgrid(x_vals, y_vals)

# Evaluate the function on the meshgrid
Z = j_func(X, Y)

# Create the contour plot
plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour Plot of j(x, y) = x^2 - 2xy + y^2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def gaussian_2d(x, y, sigma=1):
    return np.exp(-(x**2 + y**2) / (2 * sigma**2))

# Generate x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate the function values for each (x, y) pair
Z = gaussian_2d(X, Y)

# Create the filled contour plot
plt.figure(figsize=(8, 6))
plt.contourf(X, Y, Z, cmap='plasma')
plt.colorbar(label='Function Value')
plt.title('Filled Contour Plot of 2D Gaussian Function')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
